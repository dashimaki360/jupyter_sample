# %% [markdown]
# # matplotlib写経用。超サンプル。
# 自分で作ったノートに写経して実行することで、短時間で学習できる。
# matplotlibは奥が深いのでなるべくよく使うものだけ厳選したつもり。
# 詳しく知りたいときは公式チュートリアルでも見てください。
# <https://matplotlib.org/>
#
# かなり省いてますが実用上はあんまり問題ない気がする。
#
# write by dashimaki360

# %% [markdown]
# # 0.準備編

# %% [markdown]
# ## おまじない
# dont think feel

# %%
# おまじない 
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## サンプルデータ
# 今回は適当な乱数を使う。
# - x : ランダム乱数100個
# - y : ランダム乱数100個

# %%
x = np.random.randn(100)
x
# Out:
# array([ 0.72180503,  1.5762549 , -1.38804824, -1.67603266, -1.12238989,
#         0.64747748,  0.8811508 ,  0.67160154,  0.9108923 , -0.1767216 ,
#         0.15658446,  0.02362448, -0.68374023, -0.26326428,  0.18259668,
#        -0.65439465, -0.08851118,  0.3491394 ,  1.58082405, -1.26656559,
#        -0.59107917,  0.3745678 , -1.17403757, -0.60591878, -1.13421218,
#        -0.53466625,  0.12580677,  1.43762542, -1.07300184, -0.1575829 ,
#        -0.26085372,  0.40479902, -0.3351379 , -0.7360642 ,  0.61065015,
#        -0.71724675, -0.22324782, -0.65708071, -0.34491341,  0.38508286,
#        -0.96070622,  0.00725063, -0.09646449,  0.0503592 , -1.62570136,
#         0.18707379, -1.90375267, -1.39700502,  0.69677708, -1.40639061,
#         0.76808158, -1.69988909,  1.44092755,  0.20191509,  1.49455441,
#         0.21386489, -0.40007247, -1.43930854,  0.73197783,  0.65775063,
#        -0.51862259,  1.15865097,  0.04415937,  0.44677528,  0.74676171,
#        -0.92621603,  0.93743188,  0.60847514,  0.28795775, -0.63997193,
#        -0.65089812,  1.32979953,  0.03983139, -0.45284369, -0.67680473,
#        -1.77948524, -0.10474875,  0.48653231,  0.12123639,  0.55966081,
#        -0.71733372, -0.90034303,  1.44790675, -0.6829545 , -0.23713147,
#         0.55115608, -1.59951927, -0.08748712, -0.62973411, -0.51948039,
#         0.45411624, -0.2339268 , -0.29837816, -0.17652338, -0.7320938 ,
#         1.44590892,  0.65836062, -0.79954388, -0.71271279, -0.20923035])

# %%
y = np.random.randn(100)
y
# Out:
# array([  1.21863559e+00,  -1.37540823e+00,  -1.48216202e+00,
#         -2.79641204e-01,   9.58060127e-02,  -8.07344570e-01,
#         -2.39928894e-01,  -3.93503084e-01,  -2.75529144e-01,
#         -6.13436146e-01,  -1.25572696e+00,   7.54560482e-01,
#          4.93985169e-01,   1.95873047e-01,  -3.72893100e-02,
#         -6.68313759e-01,   1.22516041e+00,   3.99376539e-01,
#         -8.05673319e-01,   1.13930580e+00,  -2.11889051e-01,
#         -1.13478717e+00,   4.45216583e-01,  -2.51023667e-01,
#          7.97666906e-01,  -2.34501794e-01,  -1.56311234e+00,
#          1.55684797e+00,   7.61990074e-01,  -9.40604512e-01,
#          1.63097626e-01,   5.97702204e-01,  -2.69962355e+00,
#         -2.90640681e-02,   2.81699163e+00,   1.23768016e+00,
#          2.87005425e-01,  -9.44772944e-01,  -9.13201115e-01,
#         -7.46842642e-01,   2.87489146e+00,  -1.41287071e-01,
#          1.74523844e+00,   9.92850540e-01,   1.53964562e-04,
#          1.48050675e+00,  -1.62393478e+00,   1.44636339e+00,
#         -4.27077414e-01,   5.27553190e-01,   3.34137183e-02,
#         -1.14188459e+00,  -1.78225607e+00,  -1.48889771e+00,
#          8.18182943e-01,  -2.81464987e-01,   2.95206368e-01,
#          3.87258214e-01,   2.18357362e+00,   9.51876076e-01,
#          1.73086837e+00,   2.02138625e+00,  -1.12123311e+00,
#          3.14017317e-01,   2.46900540e-01,   1.20037890e+00,
#          1.16697321e+00,  -5.46866392e-01,   1.28492372e+00,
#          1.48571413e+00,   2.83318513e-01,  -8.74934078e-01,
#          1.90937779e-01,  -5.29022231e-01,   1.64610586e+00,
#         -1.27995930e-01,  -5.29005755e-01,   7.71229060e-02,
#          2.58559920e-01,  -7.47624565e-01,   4.51612628e-01,
#          1.20046377e+00,  -1.50308326e+00,   1.03635060e+00,
#          6.80440983e-01,  -1.30059777e+00,  -1.15584942e+00,
#         -5.73984928e-01,  -1.17199504e-01,   2.39219333e-01,
#         -7.39756340e-01,  -3.89823511e-01,   2.04268435e+00,
#          9.12382293e-01,  -5.75791954e-01,  -6.46303923e-01,
#          8.25177604e-02,   2.62088036e-01,  -3.44594978e-01,
#          2.09429188e+00])

# %% [markdown]
# # 1.グラフ書く編

# %% [markdown]
# ## 折れ線

# %%
# ふつう
plt.plot(x)

# %%
# 重ねる
plt.plot(x)
plt.plot(y)

# %% [markdown]
# ## 棒グラフ

# %%
# 普通
plt.bar(range(100), x)
# Out:
# <Container object of 100 artists>

# %%
# 重ねる
plt.bar(range(100), x)
plt.bar(range(100), y)
# Out:
# <Container object of 100 artists>

# %% [markdown]
# ## 散布図

# %%
# ふつう
plt.scatter(x,y)

# %% [markdown]
# ## ヒストグラム

# %%
# ふつう
plt.hist(x)
# Out:
# (array([  1.,   2.,   9.,  16.,  28.,  19.,  17.,   4.,   2.,   2.]),
#  array([-2.90625242, -2.33980427, -1.77335612, -1.20690797, -0.64045982,
#         -0.07401167,  0.49243648,  1.05888463,  1.62533278,  2.19178092,
#          2.75822907]),
#  <a list of 10 Patch objects>)

# %%
# 細かさ設定 大きいと細かくなる
plt.hist(x, bins=30)
# Out:
# (array([  1.,   3.,   2.,   1.,   3.,   1.,   3.,   1.,   3.,   1.,  13.,
#           5.,   2.,   3.,   8.,   5.,   5.,   4.,   4.,   4.,   3.,   5.,
#           7.,   2.,   2.,   0.,   1.,   1.,   4.,   3.]),
#  array([-1.90375267, -1.78760012, -1.67144756, -1.555295  , -1.43914244,
#         -1.32298989, -1.20683733, -1.09068477, -0.97453221, -0.85837966,
#         -0.7422271 , -0.62607454, -0.50992199, -0.39376943, -0.27761687,
#         -0.16146431, -0.04531176,  0.0708408 ,  0.18699336,  0.30314592,
#          0.41929847,  0.53545103,  0.65160359,  0.76775615,  0.8839087 ,
#          1.00006126,  1.11621382,  1.23236638,  1.34851893,  1.46467149,
#          1.58082405]),
#  <a list of 30 Patch objects>)

# %%
# 重ねる
plt.hist(x)
plt.hist(y)
# Out:
# (array([  1.,   2.,  11.,  17.,  20.,  19.,  13.,  11.,   4.,   2.]),
#  array([-2.69962355, -2.14217205, -1.58472055, -1.02726905, -0.46981754,
#          0.08763396,  0.64508546,  1.20253696,  1.75998846,  2.31743996,
#          2.87489146]),
#  <a list of 10 Patch objects>)

# %%
# 重ねて半透明
plt.hist(x, alpha=0.5)
plt.hist(y, alpha=0.5)
# Out:
# (array([  1.,   2.,  11.,  17.,  20.,  19.,  13.,  11.,   4.,   2.]),
#  array([-2.69962355, -2.14217205, -1.58472055, -1.02726905, -0.46981754,
#          0.08763396,  0.64508546,  1.20253696,  1.75998846,  2.31743996,
#          2.87489146]),
#  <a list of 10 Patch objects>)

# %%
# 積む
plt.hist([x,y], stacked=True)
# Out:
# ([array([  1.,   2.,   9.,  16.,  29.,  21.,  15.,   4.,   1.,   2.]),
#   array([  2.,   3.,  17.,  32.,  50.,  43.,  26.,  16.,   7.,   4.])],
#  array([-2.90625242, -2.32813803, -1.75002364, -1.17190925, -0.59379487,
#         -0.01568048,  0.56243391,  1.1405483 ,  1.71866268,  2.29677707,
#          2.87489146]),
#  <a list of 2 Lists of Patches objects>)

# %% [markdown]
# # 2.デコレーション編

# %% [markdown]
# ## タイトル

# %%
plt.plot(x)
plt.title("Hello Matplotlib")

# %% [markdown]
# ## 軸

# %%
# ヨコ軸
plt.plot(x)
plt.xlabel("sample nummber")

# %%
# タテ軸も
plt.plot(x)
plt.xlabel("sample nummber")
plt.ylabel("value")

# %% [markdown]
# ## 判例

# %%
# きほん
plt.plot(x, label='x')
plt.legend()

# %%
# 複数
plt.plot(x, label='x')
plt.plot(y, label='y')
plt.legend()

# %% [markdown]
# ## 描画する範囲

# %%
# 何も指定しない
plt.plot(x)

# %%
# 0 - 20 のみ
plt.plot(x)
plt.xlim(0,20)
# Out:
# (0, 20)

# %% [markdown]
# ## 色の変更

# %%
# 赤　'r'
plt.plot(x, c='r')

# %%
# 緑　'g'
plt.plot(x, c='g')

# %% [markdown]
# ## 複数並べて表示

# %%
# 複数表示
plt.plot(x)
plt.show()
plt.hist(x)
plt.show()

# %% [markdown]
# # わからないことがあったらどんどん検索とかしよう
