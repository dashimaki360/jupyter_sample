# %% [markdown]
# # matplotlib写経用。超サンプル。
# 自分で作ったノートに写経して実行することで、短時間で学習できる。
# matplotlibは奥が深いのでなるべくよく使うものだけ厳選したつもり。
# 詳しく知りたいときは公式チュートリアルでも見てください。
# <https://matplotlib.org/>
#
# かなり省いてますが実用上はあんまり問題ない気がする。
#
# write by dashimaki360

# %% [markdown]
# # 0.準備編

# %% [markdown]
# ## おまじない
# dont think feel

# %%
# おまじない 
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## サンプルデータ
# 今回は適当な乱数を使う。
# - x : ランダム乱数100個
# - y : ランダム乱数100個

# %%
x = np.random.randn(100)
x
# Out:
# array([-1.71145599,  0.10883722,  1.74315496, -0.46558403,  2.12631589,
#         0.24133287, -0.24512195,  0.45968044,  0.56434724,  0.47167459,
#         0.88277663, -0.4630499 ,  0.30204357,  0.24039734, -0.08633515,
#         0.1609373 ,  0.35938148,  1.88381896,  0.559722  ,  0.51296449,
#        -0.76448613,  1.29641488,  0.18268129,  0.01564175, -1.63204769,
#         0.37525615, -0.26141506, -0.08811941, -0.93876032,  0.11535021,
#         1.88385081,  0.16182206, -0.94037724,  0.57611542, -2.07113341,
#         1.0074625 , -0.92835067,  0.30067049, -0.87602713,  0.14050692,
#        -0.27080993,  0.39625882, -1.35201158, -1.29870001, -0.91845804,
#        -0.73489208,  0.01450896,  0.91220543,  1.16649579, -0.70698014,
#         2.20448935, -1.31189241,  0.95628514,  0.62089168, -0.17530768,
#         1.31166475,  1.72280265, -0.90731086,  0.92056352,  0.70220329,
#        -0.16656972,  0.82121386, -0.98078039, -2.74372752, -0.50900846,
#        -0.61844532,  1.88774549,  0.92347585, -0.20749816, -0.46173019,
#        -1.52127546, -0.84648806, -1.61818884, -0.52547973, -1.822579  ,
#        -1.20823072, -1.2745626 ,  0.20789004,  0.04828225,  0.3278174 ,
#         1.8433851 ,  0.90957359,  0.88641285,  0.29732836,  0.22904271,
#         1.44458724,  0.2702812 ,  1.60069974,  1.60685518,  0.62445466,
#         0.21995861, -0.02578367,  0.4632552 , -0.20065264,  0.50776716,
#         0.08253505,  1.0549081 , -0.42356171,  1.8297107 , -0.1026362 ])

# %%
y = np.random.randn(100)
y
# Out:
# array([-0.89595555,  2.0221527 , -0.26387475, -0.10009442,  1.12391445,
#        -0.28702904,  0.54349939, -0.29804673,  1.88589873, -0.02992919,
#         1.52832621, -0.79408343,  0.77354296,  0.68115302, -0.85970611,
#         1.44864264, -0.66045713,  0.51965248, -0.41199666, -0.01323321,
#         0.48251862, -0.33277939,  0.44334322, -2.36341504, -0.61783703,
#         0.4853253 , -0.89843427,  0.32884962,  1.89608576, -0.34205313,
#         0.07362947,  2.02342286, -0.23758018, -1.67969696, -0.42091985,
#         0.95808896, -0.41644205,  0.17437253, -0.55047285, -0.40645227,
#        -1.36181483,  1.18541351,  0.33529681,  0.50087048, -0.04508745,
#         0.55675102, -1.40206024, -1.17552325,  1.93149478, -0.1107071 ,
#        -1.22802819, -0.75145662, -1.86226166, -1.20839736, -2.06339893,
#        -0.85843298, -0.39745109, -0.51347159, -2.54619326, -1.15862115,
#         0.48695559,  0.7894552 ,  2.08352913,  0.12620256, -1.43341678,
#         0.67378777,  1.43432933, -0.95784302,  0.01642264, -0.55887821,
#         1.5620096 , -1.86087369, -1.52521444,  0.36903209,  0.64453211,
#         0.92462731, -1.78252734,  0.12317111, -1.25050889, -0.34819928,
#        -0.82536519, -0.50925286,  0.38960256, -0.71347073, -1.88161193,
#         2.38439477,  1.78147994,  3.41267216,  0.8331631 , -0.84267536,
#        -0.26441741,  0.40671235,  0.52151212, -0.08544205,  1.55969035,
#        -0.6033573 ,  0.79999485,  0.96460469, -1.42713168, -2.26898696])

# %% [markdown]
# # 1.グラフ書く編

# %% [markdown]
# ## 折れ線

# %%
# ふつう
plt.plot(x)

# %%
# 重ねる
plt.plot(x)
plt.plot(y)

# %% [markdown]
# ## 棒グラフ

# %%
# 普通
plt.bar(range(100), x)
# Out:
# <Container object of 100 artists>

# %%
# 重ねる
plt.bar(range(100), x)
plt.bar(range(100), y)
# Out:
# <Container object of 100 artists>

# %% [markdown]
# ## 散布図

# %%
# ふつう
plt.scatter(x,y)

# %% [markdown]
# ## ヒストグラム

# %%
# ふつう
plt.hist(x)
# Out:
# (array([  1.,   2.,   8.,  10.,  10.,  22.,  22.,  11.,   5.,   9.]),
#  array([-2.74372752, -2.24890583, -1.75408415, -1.25926246, -0.76444077,
#         -0.26961909,  0.2252026 ,  0.72002429,  1.21484597,  1.70966766,
#          2.20448935]),
#  <a list of 10 Patch objects>)

# %%
# 細かさ設定 大きいと細かくなる
plt.hist(x, bins=30)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   1.,   3.,   1.,   4.,   1.,   3.,
#           6.,   3.,   5.,   2.,   6.,   7.,   9.,  10.,   6.,   6.,   2.,
#           7.,   2.,   2.,   1.,   2.,   4.,   3.,   2.]),
#  array([-2.74372752, -2.57878696, -2.4138464 , -2.24890583, -2.08396527,
#         -1.91902471, -1.75408415, -1.58914358, -1.42420302, -1.25926246,
#         -1.0943219 , -0.92938134, -0.76444077, -0.59950021, -0.43455965,
#         -0.26961909, -0.10467852,  0.06026204,  0.2252026 ,  0.39014316,
#          0.55508372,  0.72002429,  0.88496485,  1.04990541,  1.21484597,
#          1.37978654,  1.5447271 ,  1.70966766,  1.87460822,  2.03954878,
#          2.20448935]),
#  <a list of 30 Patch objects>)

# %%
# 重ねる
plt.hist(x)
plt.hist(y)
# Out:
# (array([  4.,  10.,  13.,  22.,  16.,  19.,   7.,   7.,   1.,   1.]),
#  array([-2.54619326, -1.95030672, -1.35442018, -0.75853363, -0.16264709,
#          0.43323945,  1.02912599,  1.62501253,  2.22089908,  2.81678562,
#          3.41267216]),
#  <a list of 10 Patch objects>)

# %%
# 重ねて半透明
plt.hist(x, alpha=0.5)
plt.hist(y, alpha=0.5)
# Out:
# (array([  4.,  10.,  13.,  22.,  16.,  19.,   7.,   7.,   1.,   1.]),
#  array([-2.54619326, -1.95030672, -1.35442018, -0.75853363, -0.16264709,
#          0.43323945,  1.02912599,  1.62501253,  2.22089908,  2.81678562,
#          3.41267216]),
#  <a list of 10 Patch objects>)

# %%
# 積む
plt.hist([x,y], stacked=True)
# Out:
# ([array([  1.,   6.,  11.,  12.,  31.,  21.,   7.,  10.,   1.,   0.]),
#   array([  4.,  13.,  22.,  37.,  46.,  42.,  16.,  17.,   2.,   1.])],
#  array([-2.74372752, -2.12808755, -1.51244758, -0.89680762, -0.28116765,
#          0.33447232,  0.95011229,  1.56575226,  2.18139223,  2.79703219,
#          3.41267216]),
#  <a list of 2 Lists of Patches objects>)

# %% [markdown]
# # 2.デコレーション編

# %% [markdown]
# ## タイトル

# %%
plt.plot(x)
plt.title("Hello Matplotlib")

# %% [markdown]
# ## 軸

# %%
# ヨコ軸
plt.plot(x)
plt.xlabel("sample nummber")

# %%
# タテ軸も
plt.plot(x)
plt.xlabel("sample nummber")
plt.ylabel("value")

# %% [markdown]
# ## 判例

# %%
# きほん
plt.plot(x, label='x')
plt.legend()

# %%
# 複数
plt.plot(x, label='x')
plt.plot(y, label='y')
plt.legend()

# %% [markdown]
# ## 描画する範囲

# %%
# 何も指定しない
plt.plot(x)

# %%
# 0 - 20 のみ
plt.plot(x)
plt.xlim(0,20)
# Out:
# (0, 20)

# %% [markdown]
# ## 色の変更

# %%
# 赤　'r'
plt.plot(x, c='r')

# %%
# 緑　'g'
plt.plot(x, c='g')

# %% [markdown]
# ## 複数並べて表示

# %%
# 複数表示
plt.plot(x)
plt.show()
plt.hist(x)
plt.show()

# %% [markdown]
# # わからないことがあったらどんどん検索とかしよう
